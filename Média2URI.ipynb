# %%
a = float(input())
peso_a = 2
b = float(input())
peso_b = 3
c = float(input())
peso_c = 5
nota_a = (a*peso_a)
nota_b = (b*peso_b)
nota_c = (c*peso_c)
total = (nota_a+nota_b+nota_c)
MEDIA = (total)/(peso_a+peso_b+peso_c)
print("MEDIA = ",MEDIA)
# Out:
# 4
# 5
# 6
# MEDIA =  5.3

# %%
n = 0
soma = 0
for n in range (1,7):
    n = int(input())
    if n > 0:
        n = n + 1
        
print(n,"valor(es) positivo(s)")
print("%.1f" %soma)
# Out:
# 6
# 6
# 6
# 6
# 6
# 6
# 7 valor(es) positivo(s)
# 0.0

# %%
a = float(input())
b = float(input())
c = float(input())
total = (a*2+b*3+c*5)
Media = (total)/(2+3+5)
print("MEDIA = %.2f",Media)
# Out:
# 5
# 6
# 7
# MEDIA =  6.3

# %%
A = float(input())
B = float(input())
C = float(input())

MEDIA = (A*2 + B*3 + C*5)/(10)
print("MEDIA = ", MEDIA)
# Out:
# 5
# 6
# 7
# MEDIA =  6.3

# %%
a = float(input())
b = float(input())
c = float(input())

MEDIA = ((a*2 + b*3 + c*5)/(10))
print("MEDIA = %.1f" %MEDIA)
# Out:
# 5
# 6
# 7
# MEDIA = 6.3
