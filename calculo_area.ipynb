# %%
n = 3.14159
raio = float(input())
area = n*raio**2
print("A=%.4f" %area)
# Out:
# 10
# A=314.1590

# %%
numero = int(input())
if (numero % 2 == 0):
  print("O numero digitado é par.")
else:
  print("O numero digitado é impar.")
# Out:
# 112
# O numero digitado é par.
