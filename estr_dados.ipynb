# %%
aprovado = 0

while True:
  A=int(input())
  B=int(input())
  C=float(input())
  if A==0:
    break
  elif A >= 40 and B >= 21 and C >= 7.0:
    aprovado += 1
  else:
    print(aprovado)
# Out:
# 0
# 0
# 0
