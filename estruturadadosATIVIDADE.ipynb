# %%
def mensagem(no):
  print('Digite valor', no)

no=123
mensagem(1)
print(no)
# Out:
# Digite valor 1
# 123

# %%
def pot(b, p):
    y = b ** p
    return y
def quadrado (x):
    a = pot(x,2)
    return a

n = 5 
resultado = quadrado(n)
print(resultado)

# %%
a=0
while a<=10:
    print(a)
    if a%10==0:
        a=0
    a += 1
print("Tchau ! ")

# %%
for i in range(9):
    if i!=3:
        for j in range(6):
            print("oi")

# %%
cont = 0
for i in range(3):
    cont+=i
    a=3
    while a>0:
        cont+=a
        a-=1
print(cont)

# %%
for x in range(10,0,-2):
    print("Número: ", x)

# %%
count = 0
while count <= 5:
    print(count, end="-")
    count = count + 1
    if count > 3:
        break

# %%
num = int(input("Número de 0 a 9: "))

for i in range(num,10):
    if i==5:
        break
    if i==3: 
        continue
    print(i, end="-")

# %%
i=1
x=0

while(i<99):
  x+=1
  i+=2

print(x)
# Out:
# 49

# %%
num = int(input(''))
i=0
while i<6:
  if i == num:
    break
  print(i,' ', end='')
  i+=1
else:
  print('Fim')
# Out:
# 7
# 0  1  2  3  4  5  Fim

# %%
n=0
a=1

while n<6:
  a= a * (-1)
  n= n + 1
  if a>0:
    print(n, end='-')
# Out:
# 2-4-6-

# %%
try:
  num1=int(input())
  num2=int(input())
  print(num1/num2)
except:
  print("Erro!")
# Out:
# 3
# 20
# 0.15
